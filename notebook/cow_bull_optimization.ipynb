# %% [markdown]
# ### Импортируем бибилиотеки

# %%
import pandas as pd
from sklearn.impute import KNNImputer
import numpy as np

# %% [markdown]
# ### Загрузка и предобработка данных

# %%
bulls = pd.read_csv('/content/bulls.csv')
cows = pd.read_csv('/content/cows.csv')
pedigree = pd.read_csv('/content/pedigree.csv')

# %%
bulls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 39 non-null     object
#  1   descendants_count  39 non-null     int64
#  2   ebv                39 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.0+ KB

# %%
#Заполняем пропуск EBV у одного из быков
#Так как быков мало и все данные о них ценны, выбираем метод KNNimputer для заполнения этого пропуска
imputer = KNNImputer(n_neighbors=3)
missing_ebv = imputer.fit_transform(bulls[['ebv', 'descendants_count']])
mask = bulls['ebv'].isna()
bulls.loc[mask, 'ebv'] = missing_ebv[mask.values, 0]

# %%
cows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17177 entries, 0 to 17176
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      17177 non-null  object
#  1   ebv     15328 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 268.5+ KB

# %%
cows_copy = cows.copy()
cows_copy['ebv'].fillna(cows_copy['ebv'].median(), inplace=True)
cows_copy
# Out:
# /tmp/ipython-input-42-437587970.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cows_copy['ebv'].fillna(cows_copy['ebv'].median(), inplace=True)
#                   id     ebv
# 0      RU00000090385   266.5
# 1      DE00000090396   419.9
# 2      NL00000090422  -582.8
# 3      GB00000090437   443.8
# 4      DE00000090443   173.3
# ...              ...     ...
# 17172  DE00000051612   419.9
# 17173  FR00000048066    73.4
# 17174  RU00000048290   137.7
# 17175  US00000013052  1080.2
# 17176  DE00000048341  -255.5
# ...

# %%
imputer_cows = KNNImputer(n_neighbors=7)
cows_copy_1 = cows.copy()
missing_ebv_cows = imputer_cows.fit_transform(cows[['ebv']])
mask_cows = cows_copy_1['ebv'].isna()
cows_copy_1.loc[mask_cows, 'ebv'] = missing_ebv_cows[mask_cows.values, 0]
cows_copy_1
# Out:
#                   id          ebv
# 0      RU00000090385   266.500000
# 1      DE00000090396   362.145342
# 2      NL00000090422  -582.800000
# 3      GB00000090437   443.800000
# 4      DE00000090443   173.300000
# ...              ...          ...
# 17172  DE00000051612   362.145342
# 17173  FR00000048066    73.400000
# 17174  RU00000048290   137.700000
# 17175  US00000013052  1080.200000
# 17176  DE00000048341  -255.500000
#
# [17177 rows x 2 columns]

# %%
pedigree.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94400 entries, 0 to 94399
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         94400 non-null  object
#  1   mother_id  87822 non-null  object
#  2   father_id  89562 non-null  object
# dtypes: object(3)
# memory usage: 2.2+ MB

# %%
pedigree.fillna()
# Out:
#                   id      mother_id      father_id
# 0      GB00000090350  GB00000070596  FR00000051087
# 1      DE00000090351  GB00000085021  GB00000051158
# 2      US00000090352  US00000087323  GB00000091078
# 3      FR00000090353            NaN            NaN
# 4      GB00000090358  US00000056066  NL00000050889
# ...              ...            ...            ...
# 94395  FR00000046829  FR00000026340  GB00000000557
# 94396  FR00000048066  GB00000022627  US00000001653
# 94397  RU00000048290  NL00000005019  GB00000001788
# 94398  US00000013052  DE00000028637  DE00000003760
# 94399  DE00000048341  DE00000034312  NL00000001819
#
# [94400 rows x 3 columns]

# %%
all =cows.merge(pedigree, how='left', on='id')
all
# Out:
#                   id     ebv      mother_id      father_id
# 0      RU00000090385   266.5  US00000093522  NL00000050868
# 1      DE00000090396     NaN  RU00000067677  NL00000051057
# 2      NL00000090422  -582.8  NL00000053949  NL00000050328
# 3      GB00000090437   443.8  DE00000075045  DE00000051206
# 4      DE00000090443   173.3  US00000093024  FR00000051194
# ...              ...     ...            ...            ...
# 17172  DE00000051612     NaN  US00000056574  US00000051450
# 17173  FR00000048066    73.4  GB00000022627  US00000001653
# 17174  RU00000048290   137.7  NL00000005019  GB00000001788
# 17175  US00000013052  1080.2  DE00000028637  DE00000003760
# 17176  DE00000048341  -255.5  DE00000034312  NL00000001819
#
# [17177 rows x 4 columns]
